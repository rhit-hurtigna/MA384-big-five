# %%
import pandas as pd

# %%
df = pd.read_hdf('data.h5', 'all_questions')

# %%
df
# Out:
#          openness1  openness1_E  openness2  openness2_E  openness3  \
# 0                5         3146          5         4067          4
# 1                1         2624          4         4985          4
# 2                5         1930          5         1470          2
# 3                4         3456          4         6665          5
# 4                5         8458          5         3510          5
# ...            ...          ...        ...          ...        ...
# 1015336          2         2649          4         3544          4
# 1015337          4         2560          5         6632          5
# 1015338          5         2121          5         2807          5
# 1015339          5         5024          4         4664          4
# 1015340          5         5039          5         2493          5
#
#          openness3_E  openness4  openness4_E  openness5  openness5_E  ...  \
# 0               2959          5         3411          4         2170  ...
# ...
